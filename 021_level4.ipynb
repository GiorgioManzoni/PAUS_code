# %%
import numpy as np
import matplotlib

from fase.fileio import Table

import matplotlib.pyplot as plt
# %matplotlib inline


import sqlalchemy as sqla
import pandas as pd
matplotlib.rcParams.update({'font.size': 15})

# %%
dsn = 'postgresql://readonly:PAUsc1ence@localhost:8892/dm'
engine = sqla.create_engine(dsn)

# %%
ss =  "SELECT * "
ss += "FROM paudm.photoz_bcnz as bcnz "
ss += "JOIN paudm.production as prod "
ss += "ON bcnz.production_id = prod.id "
ss += "JOIN paudm.forced_aperture_coadd_deprecated as coadd "
ss += "ON bcnz.ref_id = coadd.ref_id "
ss += "JOIN paudm.cosmos as cosmos "
ss += "ON coadd.ref_id = cosmos.paudm_id "
ss += "WHERE bcnz.production_id = 701 " #701
ss += "AND coadd.production_id = prod.input_production_id "

data2 = pd.read_sql(ss,engine)

# %%
for i in range(len(data2.columns)):
    print data2.columns[i]
# Out:
# production_id
# ref_id
# zb
# odds
# pz_width
# zb_mean
# chi2
# n_band
# ebv
# qz
# best_run
# id
# input_production_id
# pipeline
# release
# software_version
# job_id
# comments
# created
# id
# production_id
# ref_id
# ref_cat
# ra
# dec
# mag_u
# mag_err_u
# mag_g
# mag_err_g
# mag_r
# mag_err_r
# mag_i
# mag_err_i
# mag_z
# mag_err_z
# mag_Y
# mag_err_Y
# mag_NB455
# mag_err_NB455
# mag_NB465
# mag_err_NB465
# mag_NB475
# mag_err_NB475
# mag_NB485
# mag_err_NB485
# mag_NB495
# mag_err_NB495
# mag_NB505
# mag_err_NB505
# mag_NB515
# mag_err_NB515
# mag_NB525
# mag_err_NB525
# mag_NB535
# mag_err_NB535
# mag_NB545
# mag_err_NB545
# mag_NB555
# mag_err_NB555
# mag_NB565
# mag_err_NB565
# mag_NB575
# mag_err_NB575
# mag_NB585
# mag_err_NB585
# mag_NB595
# mag_err_NB595
# mag_NB605
# mag_err_NB605
# mag_NB615
# mag_err_NB615
# mag_NB625
# mag_err_NB625
# mag_NB635
# mag_err_NB635
# mag_NB645
# mag_err_NB645
# mag_NB655
# mag_err_NB655
# mag_NB665
# mag_err_NB665
# mag_NB675
# ...

# %%
data2
# Out:
#        production_id  ref_id     zb      odds  pz_width   zb_mean      chi2  \
# 0                701      30  0.220  0.914681     0.004  0.220728   84.9086
# 1                701   16403  0.496  0.147674     0.083  0.518505   58.1914
# 2                701   16377  0.293  0.493465     0.028  0.302284  146.0240
# 3                701   16360  0.455  0.481359     0.021  0.455712   44.8399
# 4                701   16399  0.746  0.266685     0.059  0.753256   40.9172
# 5                701   16386  0.696  0.681045     0.016  0.695278   65.8057
# 6                701   16368  0.797  0.353628     0.052  0.785194   49.5776
# 7                701   16424  0.687  0.275492     0.057  0.691938   44.7815
# 8                701   16288  1.108  0.709965     0.208  1.051900  103.2850
# 9                701   16420  0.822  0.180078     0.161  0.825362   50.0867
# 10               701   16491  0.293  0.384137     0.077  0.291288   43.9542
# ...

# %%
#data852 = np.loadtxt('../data/level4_PAUS.txt',encoding='utf-8',delimiter=' ')

# %%
pd.read_table('../data/level4_PAUS.txt',encoding='utf-8',delimiter=' ')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-3-0f30943b1519> in <module>()
# ----> 1 pd.read_table('../data/level4_PAUS.txt',encoding='utf-8',delimiter=' ')
#
# ...

# %%
data852 = Table('../data/level4_PAUS.txt')

# %%
len(data852.getCol('band'))
# Out:
# 32821

# %%
from astropy import fits
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-b04996145dcb> in <module>()
# ----> 1 from astropy import fits
#
# ImportError: cannot import name fits

# %%
DATA_852 = pd.read_csv('../data/level4_PAUS.csv')

# %%
DATA_852.columns.values
# Out:
# array(['ref_id_1', 'zb', 'odds', 'pz_width', 'zb_mean', 'chi2_1',
#        'n_band', 'ebv', 'qz', 'best_run', 'production_id_1',
#        'production_id_2', 'ref_id_2', 'band', 'flux', 'flux_error',
#        'chi2_2', 'n_coadd', 'run', 'paudm_id', 'ra', 'dec', 'zp_gal',
#        'zl68_gal', 'zu68_gal', 'zl99_gal', 'zu99_gal', 'zp_sec', 'dchi',
#        'imag', 'ei', 'i_auto', 'nbfilt', 'mod_gal', 'type', 'umag',
#        'bmag', 'vmag', 'gmag', 'rmag', 'zmag', 'icmag', 'jmag', 'kmag',
#        'mv', 'ebv_gal', 'ebv_int', 'acs_a_image', 'acs_b_image',
#        'acs_theta_image', 'acs_mag_auto', 'acs_magerr_auto', 'zspec',
#        'conf', 'f814w', 'zfits', 'r50', 'sersic_n_gim2d'], dtype=object)

# %%
len(DATA_852)
# Out:
# 32821

# %%
sel = np.where(DATA_852['band']!='NB455')
a = np.array(DATA_852['band'])
a[sel]
# Out:
# array(['NB465', 'NB475', 'NB465', 'NB465', 'NB465', 'NB465', 'NB465',
#        'NB465', 'NB465', 'NB465', 'NB465', 'NB465', 'NB465', 'NB475',
#        'NB465', 'NB465', 'NB465', 'NB465', 'NB465', 'NB465', 'NB465',
#        'NB525', 'NB465', 'NB465', 'NB465', 'NB465', 'NB465', 'NB465',
#        'NB465', 'NB465', 'NB465', 'NB465', 'NB465', 'NB465', 'NB465',
#        'NB465', 'NB465', 'NB465', 'NB465', 'NB465', 'NB465', 'NB465',
#        'NB465', 'NB465', 'NB465', 'NB465', 'NB465', 'NB475', 'NB475',
#        'NB475', 'NB465', 'NB465', 'NB475', 'NB475', 'NB475', 'NB475',
#        'NB475', 'NB475', 'NB475', 'NB475', 'NB475', 'NB475', 'NB475',
#        'NB475', 'NB475', 'NB475', 'NB475', 'NB475', 'NB475', 'NB475',
#        'NB475', 'NB475', 'NB475', 'NB475', 'NB475', 'NB475', 'NB475',
#        'NB475', 'NB475', 'NB475', 'NB475', 'NB475', 'NB475', 'NB475',
#        'NB475', 'NB475', 'NB475', 'NB475', 'NB475', 'NB475', 'NB475',
# ...

# %%
ref_id = DATA_852['ref_id_1']
band = DATA_852['band']

# %%
ids = np.unique(ref_id)

# %%
len(ids)
# Out:
# 32821

# %%
DATA_852['ref_id_1','band']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-34b137326d19> in <module>()
# ----> 1 DATA_852['ref_id_1','band']
#
# /Users/giorgiomanzoni/pngs_anaconda/anaconda2/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /Users/giorgiomanzoni/pngs_anaconda/anaconda2/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ...

# %% [markdown]
# # Good table

# %%
data_good = pd.read_csv('../data/level4_PAUS_good.csv')

# %%
len(data_good)
# Out:
# 1860112

# %%
len(np.unique(data_good['ref_id_1']))
# Out:
# 47236

# %%
#data_good.to_csv('../data/level4_PAUS_good.txt', header=None, index=None, sep=' ', mode='a')

# %%
#np.loadtxt('../data/level4_PAUS_good.txt',encoding='utf-8')

# %%
data_good
# Out:
#          ref_id_1     zb      odds  pz_width   zb_mean     chi2_1  n_band  \
# 0               4  0.586  0.233880     0.071  0.586571  34.538513    46.0
# 1               4  0.586  0.233880     0.071  0.586571  34.538513    46.0
# 2               4  0.586  0.233880     0.071  0.586571  34.538513    46.0
# 3               4  0.586  0.233880     0.071  0.586571  34.538513    46.0
# 4               4  0.586  0.233880     0.071  0.586571  34.538513    46.0
# 5               4  0.586  0.233880     0.071  0.586571  34.538513    46.0
# 6               4  0.586  0.233880     0.071  0.586571  34.538513    46.0
# 7               4  0.586  0.233880     0.071  0.586571  34.538513    46.0
# 8               4  0.586  0.233880     0.071  0.586571  34.538513    46.0
# 9               4  0.586  0.233880     0.071  0.586571  34.538513    46.0
# 10              4  0.586  0.233880     0.071  0.586571  34.538513    46.0
# 11              4  0.586  0.233880     0.071  0.586571  34.538513    46.0
# ...

# %%
data_good.columns.values
# Out:
# array(['ref_id_1', 'zb', 'odds', 'pz_width', 'zb_mean', 'chi2_1',
#        'n_band', 'ebv', 'qz', 'best_run', 'production_id_1',
#        'production_id_2', 'ref_id_2', 'band', 'flux', 'flux_error',
#        'chi2_2', 'n_coadd', 'run', 'GroupID', 'GroupSize', 'paudm_id',
#        'ra', 'dec', 'zp_gal', 'zl68_gal', 'zu68_gal', 'zl99_gal',
#        'zu99_gal', 'zp_sec', 'dchi', 'imag', 'ei', 'i_auto', 'nbfilt',
#        'mod_gal', 'type', 'umag', 'bmag', 'vmag', 'gmag', 'rmag', 'zmag',
#        'icmag', 'jmag', 'kmag', 'mv', 'ebv_gal', 'ebv_int', 'acs_a_image',
#        'acs_b_image', 'acs_theta_image', 'acs_mag_auto',
#        'acs_magerr_auto', 'zspec', 'conf', 'f814w', 'zfits', 'r50',
#        'sersic_n_gim2d'], dtype=object)

# %%
plt.hist(data_good['r50'][data_good['r50']>0],bins=30)
# Out:
# (array([7.9330e+03, 1.0949e+04, 7.2190e+03, 3.0620e+03, 1.1860e+03,
#         5.1300e+02, 2.3500e+02, 1.1700e+02, 6.4000e+01, 4.1000e+01,
#         1.2000e+01, 1.2000e+01, 8.0000e+00, 4.0000e+00, 0.0000e+00,
#         3.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00, 1.0000e+00,
#         1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([  3.70434   ,  13.33042867,  22.95651733,  32.582606  ,
#          42.20869467,  51.83478333,  61.460872  ,  71.08696067,
#          80.71304933,  90.339138  ,  99.96522667, 109.59131533,
#         119.217404  , 128.84349267, 138.46958133, 148.09567   ,
#         157.72175867, 167.34784733, 176.973936  , 186.60002467,
#         196.22611333, 205.852202  , 215.47829067, 225.10437933,
#         234.730468  , 244.35655667, 253.98264533, 263.608734  ,
#         273.23482267, 282.86091133, 292.487     ]),
#  <a list of 30 Patch objects>)

# %%
data_good['band']
# Out:
# 0          NB455
# 1          NB465
# 2          NB475
# 3          NB485
# 4          NB495
# 5          NB505
# 6          NB515
# 7          NB525
# 8          NB535
# 9          NB545
# 10         NB555
# 11         NB565
# 12         NB575
# 13         NB585
# 14         NB595
# 15         NB605
# 16         NB615
# 17         NB625
# 18         NB635
# 19         NB645
# 20         NB655
# 21         NB665
# 22         NB675
# 23         NB685
# 24         NB695
# 25         NB705
# 26         NB715
# 27         NB725
# 28         NB735
# 29         NB745
#            ...
# 1860082    NB555
# 1860083    NB565
# 1860084    NB575
# 1860085    NB585
# 1860086    NB595
# 1860087    NB605
# 1860088    NB615
# 1860089    NB625
# 1860090    NB635
# 1860091    NB645
# 1860092    NB655
# 1860093    NB665
# 1860094    NB675
# 1860095    NB685
# 1860096    NB695
# 1860097    NB705
# 1860098    NB715
# 1860099    NB725
# 1860100    NB735
# 1860101    NB745
# 1860102    NB755
# ...

# %%
plt.hist(data_good['odds'])
# Out:
# (array([3.23600e+03, 9.84000e+02, 2.80000e+02, 3.10000e+02, 3.94000e+02,
#         4.53237e+05, 5.77954e+05, 3.26996e+05, 2.18337e+05, 2.78384e+05]),
#  array([-0.96951187, -0.77256068, -0.5756095 , -0.37865831, -0.18170712,
#          0.01524406,  0.21219525,  0.40914644,  0.60609763,  0.80304881,
#          1.        ]),
#  <a list of 10 Patch objects>)

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-14-14a379930911> in <module>()
# ----> 1 from sklearn import LASSO
#
# ImportError: cannot import name LASSO

# %%
dsn = 'postgresql://readonly:PAUsc1ence@localhost:8892/dm'
engine = sqla.create_engine(dsn)
# Out:
# /Users/giorgiomanzoni/pngs_anaconda/anaconda2/anaconda2/lib/python2.7/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
#SELECT * FROM cosmohub.paudm_photoz_bcnz as bcnz JOIN cosmos ON bcnz.ref_id = cosmos.paudm_id WHERE bcnz.production_id = 866 
#AND zspec > 0

# %%
ss =  "SELECT * FROM cosmohub.paudm_photoz_bcnz as bcnz " 
ss += "JOIN cosmos ON bcnz.ref_id = cosmos.paudm_id "
ss += "WHERE bcnz.production_id = 866 "
ss += "AND zspec > 0 "

data_jorge = pd.read_sql(ss,engine)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-11-359b7ee9a71f> in <module>()
#       4 ss += "AND zspec > 0 "
#       5
# ----> 6 data_jorge = pd.read_sql(ss,engine)
#
# /Users/giorgiomanzoni/pngs_anaconda/anaconda2/anaconda2/lib/python2.7/site-packages/pandas/io/sql.pyc in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     414             sql, index_col=index_col, params=params,
#     415             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 416             chunksize=chunksize)
#     417
#     418
#
# /Users/giorgiomanzoni/pngs_anaconda/anaconda2/anaconda2/lib/python2.7/site-packages/pandas/io/sql.pyc in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1090         args = _convert_params(sql, params)
#    1091
# -> 1092         result = self.execute(*args)
# ...
