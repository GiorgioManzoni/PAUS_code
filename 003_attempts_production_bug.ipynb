# %% [markdown]
# 𝚜𝚜𝚑 ⎯𝚕 𝚐𝚖𝚊𝚗𝚣𝚘𝚗𝚒 ⎯𝙻𝟾𝟾𝟿𝟸:𝚍𝚋𝟶𝟸.𝚙𝚊𝚞.𝚙𝚒𝚌.𝚎𝚜:𝟻𝟺𝟹𝟸 𝚞𝚒.𝚙𝚒𝚌.𝚎𝚜

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import sqlalchemy as sqla
import pandas as pd
matplotlib.rcParams.update({'font.size': 15})

# %%
dsn = 'postgresql://readonly:PAUsc1ence@localhost:8892/dm'
engine = sqla.create_engine(dsn)

# %%
s = "SELECT 'id', 'input_production', 'pipeline', 'release', 'software_version', 'job_id', 'created' FROM paudm.production"
data = pd.read_sql(s,engine)

# %%
data.columns.values
# Out:
# array([u'?column?', u'?column?', u'?column?', u'?column?', u'?column?',
#        u'?column?', u'?column?'], dtype=object)

# %%
data
# Out:
#     ?column?          ?column?  ?column? ?column?          ?column? ?column?  \
# 0         id  input_production  pipeline  release  software_version   job_id
# 1         id  input_production  pipeline  release  software_version   job_id
# 2         id  input_production  pipeline  release  software_version   job_id
# 3         id  input_production  pipeline  release  software_version   job_id
# 4         id  input_production  pipeline  release  software_version   job_id
# 5         id  input_production  pipeline  release  software_version   job_id
# 6         id  input_production  pipeline  release  software_version   job_id
# 7         id  input_production  pipeline  release  software_version   job_id
# 8         id  input_production  pipeline  release  software_version   job_id
# 9         id  input_production  pipeline  release  software_version   job_id
# 10        id  input_production  pipeline  release  software_version   job_id
# ...

# %%
pd.read_csv("2283.csv",sep=',',comment='#',na_values='\N')
# Out:
#       id  input_production  pipeline                    release  \
# 0     46              40.0     memba            PAU2015A_fpSD01
# 1    294             292.0     memba            16A-CM292-CM294
# 2    260             258.0     memba            16A-CM258-CM260
# 3    270             267.0    photoz  16A-CM258-CM267-P03-prior
# 4    144             139.0     memba            PAU2015A_fpSD06
# 5    134               1.0   nightly                PAU2015A_03
# 6    184             139.0     memba            PAU2015A_fpDE09
# 7    286             258.0     memba            16A-CM258-CM286
# 8    142             139.0     memba            PAU2015A_fpSD05
# 9    136               1.0   nightly                PAU2015A_04
# 10   188             139.0     memba            PAU2015A_fpSD11
# 11   194             139.0     memba            PAU2015A_fpSD13
# 12   240               NaN  register                  201604-W3
# 13   288             285.0     memba            16A-CM285-CM288
# ...

# %%
pd.read_csv('2282_production.csv',sep=',',comment='#',na_values='\N')
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-12-7783d4d5c710> in <module>()
# ----> 1 pd.read_csv('2282_production.csv',sep=',',comment='#',na_values='\N')
#
# ...
