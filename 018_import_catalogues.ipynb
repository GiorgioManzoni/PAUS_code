# %%
from prova import *
import sys
del sys.modules

# %%
np.median([1,2,3git
# Out:
# 2.0

# %%
CIAO = ciao()

# %%
CIAO.io
# Out:
# 'Giorgio'

# %%
from catalogues import *

# %%
cosmos = COSMOS()

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(cosmos.ra,cosmos.dec,',',alpha=0.1)
plt.show()
